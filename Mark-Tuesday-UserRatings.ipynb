# %% [markdown]
# TUESDAY: Deep dive into the vote_average data in TMDB_Movies file

# %%
import pandas as pd
import numpy as np

# %%
TMDB_Movies = pd.read_csv("tmdb.movies.csv")

print(type(TMDB_Movies))
print(TMDB_Movies.shape)
print(TMDB_Movies.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (26517, 10)
# Unnamed: 0             int64
# genre_ids             object
# id                     int64
# original_language     object
# original_title        object
# popularity           float64
# release_date          object
# title                 object
# vote_average         float64
# vote_count             int64
# dtype: object

# %%
TMDB_Movies.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %% [markdown]
# The important files here will be: vote_average; title; release_date; possibly genre_ids

# %%
# Genre ID mapping from Yish - not sure how to proceed with this?
# what are the keys within "genres" list of dictionaries?
genre_dict = {"genres":[{"id":28,"name":"Action"},{"id":12,"name":"Adventure"},{"id":16,"name":"Animation"},{"id":35,"name":"Comedy"},{"id":80,"name":"Crime"},{"id":99,"name":"Documentary"},{"id":18,"name":"Drama"},{"id":10751,"name":"Family"},{"id":14,"name":"Fantasy"},{"id":36,"name":"History"},{"id":27,"name":"Horror"},{"id":10402,"name":"Music"},{"id":9648,"name":"Mystery"},{"id":10749,"name":"Romance"},{"id":878,"name":"Science Fiction"},{"id":10770,"name":"TV Movie"},{"id":53,"name":"Thriller"},{"id":10752,"name":"War"},{"id":37,"name":"Western"}]}
len(genre_dict)
# type(genre_dict)
# Out:
# 1

# %%
# Lets double check for missing values: there are none for any of our columns of interest
TMDB_Movies.genre_ids.isna().sum()
# Out:
# 0

# %%
# Start working on the release_date column - try sort on the text(object)
TMDB_Movies.sort_values('release_date')
TMDB_Movies.head(20)
# Out:
#     Unnamed: 0                 genre_ids     id original_language  \
# 0            0           [12, 14, 10751]  12444                en
# 1            1       [14, 12, 16, 10751]  10191                en
# 2            2             [12, 28, 878]  10138                en
# 3            3           [16, 35, 10751]    862                en
# 4            4             [28, 878, 12]  27205                en
# 5            5           [12, 14, 10751]  32657                en
# 6            6         [28, 12, 14, 878]  19995                en
# 7            7           [16, 10751, 35]  10193                en
# 8            8           [16, 10751, 35]  20352                en
# 9            9  [16, 28, 35, 10751, 878]  38055                en
# 10          10           [16, 35, 10751]    863                en
# 11          11           [10751, 14, 12]  12155                en
# 12          12              [53, 12, 28]  27578                en
# ...

# %%
# Try converting to a integer? - try removing dashes and then to integer? - look into work with date format?
# TMDB_Movies['release_date'] = TMDB_Movies['release_date'].astype(int)

# %%
TMDB_Movies.sort_values('vote_average') # not work so well? Stry spaces?
TMDB_Movies.tail(200)
# Out:
#        Unnamed: 0        genre_ids      id original_language  \
# 26317       26317             [99]  518844                en
# 26318       26318             [99]  517695                en
# 26319       26319               []  517345                en
# 26320       26320               []  516523                en
# 26321       26321             [99]  516060                de
# ...           ...              ...     ...               ...
# 26512       26512         [27, 18]  488143                en
# 26513       26513         [18, 53]  485975                en
# 26514       26514     [14, 28, 12]  381231                en
# 26515       26515  [10751, 12, 28]  366854                en
# 26516       26516         [53, 27]  309885                en
#
#                                   original_title  popularity release_date  \
# 26317                             Time For Ilhan         0.6   2018-04-21
# 26318                           In Search of Ozu         0.6   2018-04-16
# ...

# %%
TMDB_Movies.sort_values(by='vote_average',ascending=False, inplace=True)
TMDB_Movies.head(200)
# Out:
#      Unnamed: 0            genre_ids     id original_language  \
# 0             0      [12, 14, 10751]  12444                en
# 1             1  [14, 12, 16, 10751]  10191                en
# 2             2        [12, 28, 878]  10138                en
# 3             3      [16, 35, 10751]    862                en
# 4             4        [28, 878, 12]  27205                en
# ..          ...                  ...    ...               ...
# 195         195          [18, 10749]  48650                es
# 196         196          [18, 10749]  42297                en
# 197         197             [35, 18]  56272                en
# 198         198         [18, 53, 80]  68341                ja
# 199         199  [14, 18, 27, 10749]  52587                de
#
#                                    original_title  popularity release_date  \
# 0    Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...
